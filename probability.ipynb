# %% [markdown]
# ## probability in statistics/HW3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sampstdev(arr):
    avg = np.average(arr)
    total = 0
    for val in arr: 
        total += (val - avg)**2
    return (total/(len(arr)-1))**.5

def reshape(data):
    data = data.split()
    data = list(map(lambda val: float(val), data))
    data = np.array(data)
    return data

def probability(arr):
    pass
    #calculate relative frequency

# %%
data1 = """29.4
26.38
26.5
26.55
26.87
26.61
29.33
26.67
26.09
29.32
27.12
26.83
27.04
29.17
27.04
29.19
26.26
26.16
26.7
28.78
29.33
27.27
28.9
29.14
29.23
28.32
27.12
27.05
28.44
26.97
27.52
26.79
26.54
26.7
28.97
28.84
26.71
26.4
26.91
27.98
29.12"""
data1 = reshape(data1)
print(np.percentile(data1, [25, 50, 75]))
plt.hist(data1)
plt.show()
# Out:
# [26.7  27.05 28.9 ]

# %%
data2 = """98.0
97.6
98.8
98.0
98.8
98.8
97.6
98.6
98.6
98.8
98.0
98.2
98.0
98.0
97.0
97.2
98.2
98.2
98.5
98.5
99.0
98.0
97.0
97.3
97.3
98.1
97.8
99.0
97.6
97.4
98.0
97.4
98.0
98.6
98.6
98.4
97.0
99.0
98.0
99.4
97.8
98.2
99.2
99.0
97.7
98.2
98.2
98.8
98.1
98.5
97.2
98.5
99.2
98.3
98.7
98.8
98.6
98.0
99.1
97.2
97.6
97.9
98.8
98.6
98.6
99.3
98.7
99.3
97.8
97.7
98.3
97.7
97.1
98.4
98.6
97.4
96.7
96.9
98.4
98.2
98.6
97.0
97.4
98.4
97.4
96.8
98.2
97.4
98.0"""
data2 = reshape(data2)
print(np.percentile(data2, [0, 25, 50, 75, 100]))
plt.boxplot(data1)
plt.show()
# Out:
# [96.7 97.6 98.2 98.6 99.4]

# %% [markdown]
# ### probability is the same as relative frequency
# ### odds is the ratio of specified elements to non specified
